# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
mpl.rc('font',family='Arial')

# %%
df = pd.read_csv('Y:/py/longprofiles.csv')
df.head()
# Out:
#    river1_main  r1m_b    r1m_s  river1_trib0     r1t0_b   r1t0_s  \
# 0     0.000000    NaN -54.2930   4741.668000 -46.067799 -45.8678
# 1    10.776883    NaN -54.6030   4752.729529 -46.511501 -46.2042
# 2    21.553766    NaN -54.8403   4763.791059 -47.297001 -46.8526
# 3    32.330650    NaN -55.1879   4774.852588 -46.654800 -46.2738
# 4    43.107533    NaN -54.9828   4785.914118 -46.596802 -46.1022
#
#    river1_trib1     r1t1_b   r1t1_s  river2_main  ...   r2t2_s  river3_main  \
# 0    11698.3800 -41.005699 -42.3603     0.000000  ... -40.0754     0.000000
# 1    11710.5486 -41.446499 -42.8574    10.241590  ... -39.9640    10.131295
# 2    11722.7172 -41.963600 -43.2843    20.483179  ... -39.9114    20.262590
# 3    11734.8858 -41.762199 -43.0671    30.724769  ... -39.8412    30.393885
# 4    11747.0544 -41.968502 -43.4137    40.966359  ... -39.7794    40.525180
#
#        r3m_b    r3m_s  river3_trib0     r3t0_b   r3t0_s  river3_trib1  \
# ...

# %%
plt.plot(df.river1_main,df.r1m_s,color='#74a9cf',linewidth=0.5)
plt.plot(df.river1_trib0,df.r1t0_s,color='#0570b0',linewidth=0.5)
plt.plot(df.river1_trib1,df.r1t1_s,color='#023858',linewidth=0.5)
plt.xlim(0,20000)
plt.ylim(-64,-30)
plt.xlabel('profile distance (m)',fontsize=22)
plt.ylabel('elevation (m OD)',fontsize=22)
plt.xticks(np.arange(0,21000,step=1000),fontsize=18)
plt.yticks(np.arange(-64,-28,step=2),fontsize=18)
plt.legend(('main','trib1','trib2'),fontsize=22,loc=4)
plt.minorticks_on()
plt.title('Channel 1',fontsize=22,loc='left',pad=-20)
fig = plt.gcf()
fig.set_size_inches(20,5)
plt.tight_layout()
plt.savefig('river1.png')
plt.savefig('river1.svg')

# %%
plt.plot(df.river2_main,df.r2m_s,color='#1d91c0',linewidth=0.5)
plt.plot(df.river2_trib0,df.r2t0_s,color='#225ea8',linewidth=0.5)
plt.plot(df.river2_trib1,df.r2t1_s,color='#253494',linewidth=0.5)
plt.plot(df.river2_trib2,df.r2t2_s,color='#081d58',linewidth=0.5)
plt.xlim(0,32000)
plt.ylim(-54,-30)
plt.xlabel('profile distance (m)',fontsize=22)
plt.ylabel('elevation (m OD)',fontsize=22)
plt.xticks(np.arange(0,33000,step=2000),fontsize=18)
plt.yticks(np.arange(-54,-28,step=2),fontsize=18)
plt.legend(('main','trib1','trib2','trib3'),fontsize=22,loc=4)
plt.minorticks_on()
plt.title('Channel 2',fontsize=22,loc='left',pad=-20)
fig = plt.gcf()
fig.set_size_inches(20,5)
plt.tight_layout()
plt.savefig('river2.png')
plt.savefig('river2.svg')

# %%
plt.plot(df.river3_main,df.r3m_b,color='#6baed6',linewidth=0.5)
plt.plot(df.river3_trib0,df.r3t0_b,color='#2171b5',linewidth=0.5)
plt.plot(df.river3_trib1,df.r3t1_b,color='#08306b',linewidth=0.5)
plt.xlim(0,25000)
plt.ylim(-54,-28)
plt.xlabel('profile distance (m)',fontsize=22)
plt.ylabel('elevation (m OD)',fontsize=22)
plt.xticks(np.arange(0,26000,step=1000),fontsize=18)
plt.yticks(np.arange(-54,-26,step=2),fontsize=18)
plt.legend(('main','trib1','trib2','trib3'),fontsize=22,loc=4)
plt.minorticks_on()
plt.title('Channel 3',fontsize=22,loc='left',pad=-20)
fig = plt.gcf()
fig.set_size_inches(20,5)
plt.tight_layout()
plt.savefig('river3.png')
plt.savefig('river3.svg')
